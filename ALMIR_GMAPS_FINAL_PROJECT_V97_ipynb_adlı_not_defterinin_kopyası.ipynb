# %% [markdown]
# <a href="https://colab.research.google.com/github/nokill0054/Accountant/blob/master/ALMIR_GMAPS_FINAL_PROJECT_V97_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python
# coding: utf-8
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

opt = Options()
opt.add_argument("--headless")
browser = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opt)





#gmaps = googlemaps.client(key='AIzaSyCG0hQthcFlThlv9-0mJtDNb-JdKrfaCd4')

#driver_path = "C:\\Users\Bulent\Desktop\python webscraping\selenium\etsy\chromedriver.exe"
#absolute path: araştır.
# browser = webdriver.Chrome(ChromeDriverManager().install())

#browser = webdriver.Chrome(driver_path)
wait = WebDriverWait(browser,300)

Shop_name = input("Entering Shops Name : \n for example (Flower Shops) \n ")
Shop_location = input("Entering Shop Location : \n for example (New York) \n ")
Page = int(input("How many Page do you want to scrap? \n 5 pages are Optimum \n "))
print("Searching for your query \n Please wait....")


#place_name = (Shop_name+ " "+ Shop_location)
#place_result = gmaps.places(place_name)
#place_result

headers_param = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"}

browser.get("https://www.google.com/maps/@-10.5187555,-123.8099325,5z")
browser.maximize_window()


#browser.find_element_by_xpath("//*[@id='yDmH0d']/c-wiz/div/div/div/div[2]/div[1]/div[4]/form/div[1]/div/button/span").click()

shops_name_entering = wait.until(EC.presence_of_element_located
(
        (By.CLASS_NAME,
         'tactile-searchbox-input')))

shops_name_entering1 =browser.find_element_by_class_name("tactile-searchbox-input")
shops_name_entering.send_keys(Shop_name+ " "+ Shop_location)
time.sleep(2)

shops_name_entering.send_keys(Keys.ENTER)
time.sleep(2)

#def main():

google_maps_click = browser.find_element_by_xpath("//*[@id='searchbox']/div[1]")
google_maps_click.click()
time.sleep(10)

#next= browser.find_element_by_xpath("#//*[@id='ppdPk-Ej1Yeb-LgbsSe-tJiF1e']").click

def begin():
    #sayfanın yüklenmesini beklemek için
    element = wait.until(EC.element_to_be_clickable(
        (By.XPATH,
         "//*[@id='pane']/div/div[1]/div/div/div[4]/div[1]/div[1]/div/a")))

    
    shop_click = browser.find_element_by_xpath("//*[@id='pane']/div/div[1]/div/div/div[4]/div[1]/div[1]/div/a").click() 
    
    
    
                                                    
    try:
        time.sleep(10)
        #shop_phone = browser.find_element_by_css_selector("[data-tooltip='Copy phone number']")
        shop_phone =browser.find_element_by_xpath("//*[@id='pane']//button[@data-tooltip='Telefon numarasını kopyala']//div[@class='QSFF4-text gm2-body-2']").text
        print(shop_phone)
        #time.sleep(10)
    except:
        print("There is no Phone Number")


    maps_page = browser.page_source
    #print(maps_page)
    shops_soup = BeautifulSoup(maps_page, "lxml")
    time.sleep(10)

    try:
        shop_name = shops_soup.find("h1", attrs = {"class" : "x3AX1-LfntMc-header-title-title gm2-headline-5"}).text
        print (shop_name)
    except:
        print("There is no Shop name")

    try:
        shop_point = shops_soup.find("span", attrs = {"class" : "aMPvhf-fI6EEc-KVuj8d"}).text
        print(shop_point)
    except:
        print("There is no Shop point")

    try:
        shop_review = shops_soup.find("button", attrs = {"class" : "widget-pane-link"}).text
        print(shop_review)
    except:
        print("There is no Shop Review")

    try:
        shop_group = shops_soup.find("button", attrs = {"jsan" : "7.widget-pane-link,0.jsaction"}).text
        print(shop_group)
    except:
        print("There is no Shop Group")

    try:
        shop_adr= shops_soup.find("div", attrs = {"class" : "QSFF4-text gm2-body-2"}).text
        print(shop_adr)
    except:
        print("There is no Shop Adress")

    try:
        shop_hours= shops_soup.find("span", attrs = {"class" :"LJKBpe-Tswv1b-hour-text"}).text
        print(shop_hours)
    except: 
        print("There is no Shop hours")

    try:
        shop_web = shops_soup.find("div", attrs ={"class" : "rogA2c HY5zDd"}).text
        print(shop_web)
    except:
        print("There is no Shop web")


    i = 2

    while i<=22: 
        
        #element = wait.until(EC.element_to_be_clickable(
        #(By.XPATH,
         #"//*[@id='pane']/div/div[1]/div/div/div[4]/div[1]/div[1]/div/a")))
        
        shop_click = browser.find_element_by_xpath("//*[@id='bottom-pane']/div/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div["+str(i)+"]").click() 
        time.sleep(10)

        try:
            #shop_phone = browser.find_element_by_css_selector("[data-tooltip='Copy phone number']")
            shop_phone =browser.find_element_by_xpath("//*[@id='pane']//button[@data-tooltip='Telefon numarasını kopyala']//div[@class='QSFF4-text gm2-body-2']").text
            print(shop_phone)
            time.sleep(10)
        except:
            print("There is no Phone Number")


        maps_page = browser.page_source
        #print(maps_page)
        shops_soup = BeautifulSoup(maps_page, "lxml")
        time.sleep(10)
        
        try:
            shop_name = shops_soup.find("h1", attrs = {"class" : "x3AX1-LfntMc-header-title-title gm2-headline-5"}).text
            print (shop_name)
        except:
            print("There is no Shop name")
        
        try:
            shop_point = shops_soup.find("span", attrs = {"class" : "aMPvhf-fI6EEc-KVuj8d"}).text
            print(shop_point)
        except:
            print("There is no Shop point")
        
        try:
            shop_review = shops_soup.find("button", attrs = {"class" : "widget-pane-link"}).text
            print(shop_review)
        except:
            print("There is no Shop Review")
        
        try:
            shop_group = shops_soup.find("button", attrs = {"jsan" : "7.widget-pane-link,0.jsaction"}).text
            print(shop_group)
        except:
            print("There is no Shop Group")
            
        try:
            shop_adr= shops_soup.find("div", attrs = {"class" : "QSFF4-text gm2-body-2"}).text
            print(shop_adr)
        except:
            print("There is no Shop Adress")
        
        try:
            shop_hours= shops_soup.find("span", attrs = {"class" :"LJKBpe-Tswv1b-hour-text"}).text
            print(shop_hours)
        except: 
            print("There is no Shop hours")
        
        try:
            shop_web = shops_soup.find("div", attrs ={"class" : "rogA2c HY5zDd"}).text
            print(shop_web)
        except:
            print("There is no Shop web")
        
        #shop_phone = shops_soup.find("button", attrs = {"ved" : "1i:0,t:18491,e:18,p:RGHKYPWwIdCQ8gLJt7bwBA:174"})
        #print(shop_phone.text)

        #browser.execute_script("window.history.go(-1)")
        #time.sleep(10)
        print("--------------",i,". sayfa------------------")
        i=i+1
time.sleep(5)        
try:
    begin()
except:
    print("hata")
  
    

j=1     
while j<=Page:
    #sonraki sayfaya geçirir
    #element = wait.until(EC.element_to_be_clickable(
        #(By.XPATH,
         #"//*[@id='omnibox-singlebox']/div[1]/div[4]/div/div[1]/div/div/button/span")))
    
                                    
    browser.find_element_by_xpath("//*[@id='omnibox-singlebox']/div[1]/div[4]/div/div[1]/div/div/button/span").click()
    time.sleep(10)
    
    #element = wait.until(EC.element_to_be_clickable(
        #(By.CSS_SELECTOR,
         #"#ppdPk-Ej1Yeb-LgbsSe-tJiF1e > img")))
    
    browser.find_element_by_css_selector("#ppdPk-Ej1Yeb-LgbsSe-tJiF1e > img").click()
    time.sleep(10)
    begin()
    j=j+1

print("Tarama bitti.")

df = pd.DataFrame(list)
df.columns=["NAME","ADDRESS","ACTIVITY","MAIL","CONTACT NO.","SCORE","REVIEW QUANTITY","OPENING HOURS"]
df.to_excel("data1.xlsx")




# df = pd.DataFrame()
# df["NAME"] = shop_name
# df["ADDRESS"] = shop_adr
# df["ACTIVITY"] = shop_group
# df["MAIL"] = shop_web
# df["CONTACT NO."] = shop_phone
# df["SCORE"] = shop_point
# df["REVIEW QUANTITY"] = shop_review
# df["Opening Hours"] = shop_hours

# # writing the DataFrame into a CSV file
# df.to_csv("ALMIR_MAPS_DATA.csv", index=None)

   
    #try:
    #wait....presence_of_element(....)
    #bir şey yap
    #except:
    #pass
    #try:

#fakat bu while yada for'un içinde bir try komutu ise
#except: continue
#olması lazım
#index'in değişmesi için

# %% [markdown]
# # Yeni Bölüm
